# %% [markdown]
# # Полиномы, НОД, расширенный Евклид
# ### Вариант 4

# %%
x = .
f := x^4 - 4*x^3 + 7*x^2 - 5*x + 1
g := x^5 - x^4 - x^3 + x^2 + 5*x - 5

TraditionalForm[f]
TraditionalForm[g]
# Out:
# FormBox[RowBox[{SuperscriptBox["x", "4"], "-",
#
#
# >        RowBox[{"4", " ", SuperscriptBox["x", "3"]}], "+",
#
#
# >        RowBox[{"7", " ", SuperscriptBox["x", "2"]}], "-", RowBox[{"5", " ", "x"}],\
#
# >    "+",
#      "1"}], TraditionalForm]
#
# FormBox[RowBox[{SuperscriptBox["x", "5"], "-", SuperscriptBox["x", "4"], "-",
#
#
# >        SuperscriptBox["x", "3"], "+", SuperscriptBox["x", "2"], "+",
#
#
# >        RowBox[{"5", " ", "x"}], "-", "5"}], TraditionalForm]

# %%
advgcd[aa_, bb_] := Module[{a=aa, b=bb, x0=1, xx=0, y0=0, yy = 1, q, r},
    While[Not[SameQ[b, 0]],
        q = PolynomialQuotient[a, b, x];
        r = PolynomialRemainder[a, b, x];
        {a, b} = {b, r};
        {x0, xx} = {xx, (x0 - xx*q)//ExpandAll};
        {y0, yy} = {yy, (y0 - yy*q)//ExpandAll};
    ];
    {a, x0, y0}
];

# %%
{gcd, u, v} = advgcd[f, g]
Simplify[gcd == f * u + g * v]
# Out:
#                                        2       3                    2
#    1936    1936 x  1264   656 x   128 x    16 x   640   880 x   16 x
# {-(----) + ------, ---- + ----- - ------ - -----, --- - ----- + -----}
#    441      441    441     441     441      21    441    441     21
# True

# %%
{gcd, {u, v}} = PolynomialExtendedGCD[f, g]
Simplify[gcd == f * u + g * v]
# Out:
#                          2       3                  2
#           79 + 41 x - 8 x  - 21 x   40 - 55 x + 21 x
# {-1 + x, {------------------------, -----------------}}
#                     121                    121
# True

# %% [markdown]
# # Падение тела

# %%
tmax := 1.41
alpha := Pi / 4
v0 := 10
k := 0.01
g := 9.81

sol = NDSolve[
    {
        y1'[t] == y2[t],
        y2'[t] == -k * y2[t] * Sqrt[y2[t] ^ 2 + y4[t] ^ 2],
        y3'[t] == y4[t],
        y4'[t] == -k * y4[t] * Sqrt[y2[t] ^ 2 + y4[t] ^ 2] - g,
        y1[0] == 0,
        y2[0] == v0 * Cos[alpha],
        y3[0] == 0,
        y4[0] == v0 * Sin[alpha]
    },
    {y1, y2, y3, y4},
    {t, 0, tmax},
    MaxSteps -> 10000
];

plt = {};

plt = Append[plt, ParametricPlot[Evaluate[{y1[t], y3[t]} /. sol[[1]]], {t, 0, tmax}, PlotRange -> {{0, 10}, {0, 3}}]];

Show[plt]
# Out:
# -Graphics-

# %% [markdown]
# # Модель «хищник – жертва»

# %%
x = .
y = .
a := 3;
c := 1;
d := 1;
colors = {Red, Green, Blue};

plt = {};
For[b = 4, b > 1, b--,
    equation1[t_] := x'[t] == x[t] * (a - b * y[t]);
    equation2[t_] := y'[t] == y[t] * (-c + d * x[t]);
    sol = NDSolve[{equation1[t], equation2[t], x[0] == 2, y[0] == 1}, {x, y}, {t, 0, 7}, MaxSteps -> 3000];
    plt = Append[plt, ParametricPlot[Evaluate[{x[t], y[t]} /. sol], {t, 0, 7}, PlotRange -> {{0, 3}, {0, 3}}, PlotStyle -> colors[[b-1]]]]
]
Show[plt]
# Out:
# -Graphics-

# %%
(* Для Wolfram Cloud *)

predatorPrey[aa_, bb_, cc_, dd_] := Module[{a = aa, b = bb, c = cc, d = dd},
    plt = {};
    eq1[t_] := x'[t] == x[t] * (a - b * y[t]);
    eq2[t_] := y'[t] == y[t] * (-c + d * x[t]);
    sol = NDSolve[{eq1[t], eq2[t], x[0] == 2, y[0] == 1}, {x, y}, {t, 0, 7}, MaxSteps -> 3000];
    plt = Append[plt, ParametricPlot[Evaluate[{x[t], y[t]} /. sol], {t, 0, 7}, PlotRange -> {{0, 3}, {0, 3}}]];
    plt
];
{min, max, step} = {1, 4, 1};
Manipulate[Show[predatorPrey[a, b, c, d]], {a, min, max, step}, {b, min, max, step}, {c, min, max, step}, {d, min, max, step}];

# %% [markdown]
# # Приведение уравнения поверхности к каноническому виду

# %%
x = .
y = .
z = .
u = .
v = .
u[x_, y_, z_] := -2*y^2 + 4*y*z - 3*z^2 + 4*y + 4*z - 12;
u[x, y, z] // TraditionalForm
# Out:
# FormBox[RowBox[{RowBox[{"-", RowBox[{RowBox[{"2"}], " ",
#
#
# >            SuperscriptBox["y", "2"]}]}], "+", RowBox[{"4", " ", "y", " ", "z"}], "+",
#
#
# >        RowBox[{"4", " ", "y"}], "-", RowBox[{"3", " ", SuperscriptBox["z", "2"]}],\
#
# >    "+",
#      RowBox[{"4", " ", "z"}], "-", "12"}], TraditionalForm]

# %%
A := {
    {0, 0, 0},
    {0, -2, 2},
    {0, 2, -3}
}
B := {0, 4, 4}
a0 := -12

MatrixForm[A]
MatrixForm[B, TableDirections -> Row]
# Out:
# 0    0    0
#
# 0    -2   2
#
# 0    2    -3
# 0 4 4

# %% [markdown]
# ### Характеристическое уравнение

# %%
l = .
AlE[l_] := A - IdentityMatrix[3] * l;
MatrixForm[AlE[l]]
det := Det[AlE[l]]
TraditionalForm[det]
# Out:
# -l       0        0
#
# 0        -2 - l   2
#
# 0        2        -3 - l
# FormBox[RowBox[{RowBox[{"-", RowBox[{SuperscriptBox["l", "3"]}]}], "-",
#
#
# >        RowBox[{"5", " ", SuperscriptBox["l", "2"]}], "-", RowBox[{"2", " ", "l"}]}],
#
#
# >      TraditionalForm]

# %%
 If[
     CharacteristicPolynomial[A, l] === det,
         Print["Ok"]
     ]
# Out:
# Ok

# %% [markdown]
# ### Собственные значения

# %%
sols = Solve[det == 0, l];
eigenvalues = l /. sols;
MatrixForm[N[eigenvalues], TableDirections -> Row]
# Out:
# 0.        -4.56155  -0.438447

# %%
lambdas := Sort[Eigenvalues[A]]
Sort[eigenvalues];

If[ lambdas === eigenvalues,
    Print["Ok"]
]
# Out:
# Ok

# %% [markdown]
# ### Собственные векторы

# %%
A1 = A - IdentityMatrix[3] * eigenvalues[[1]];
MatrixForm[A1]

A2 = A - IdentityMatrix[3] * eigenvalues[[2]];
MatrixForm[A2]

A3 = A - IdentityMatrix[3] * eigenvalues[[3]];
MatrixForm[A3]
# Out:
# 0    0    0
#
# 0    -2   2
#
# 0    2    -3
# 5 + Sqrt[17]
# ------------
#      2              0                   0
#
#                          5 + Sqrt[17]
#                     -2 + ------------
# 0                             2         2
#
#                                              5 + Sqrt[17]
#                                         -3 + ------------
# 0                   2                             2
# 5 - Sqrt[17]
# ------------
#      2              0                   0
#
#                          5 - Sqrt[17]
#                     -2 + ------------
# 0                             2         2
#
#                                              5 - Sqrt[17]
#                                         -3 + ------------
# 0                   2                             2

# %%
variables = {x, y, z};

v1 = Solve[AlE[eigenvalues[[1]]] . variables == 0][[1]];
v1 = variables /. v1 /. x -> 1;
MatrixForm[v1, TableDirections -> Row]

(*Первый вектор пришлось считать вручную, так как RowReduce определяет его неправильно*)

v2 = RowReduce[A2][[2]];
MatrixForm[v2, TableDirections -> Row]

v3 = RowReduce[A3][[2]];
MatrixForm[v3, TableDirections -> Row]
# Out:
# 1 0 0
#                             -1 + Sqrt[17]
#                             -------------
# 0             1                   4
#                             -1 - Sqrt[17]
#                             -------------
# 0             1                   4

# %% [markdown]
# ### Матрица перехода из нормированных собственных векторов

# %%
nv1 := Normalize[v1]
nv2 := Normalize[v2]
nv3 := Normalize[v3]

S := {nv1, nv2, nv3}
MatrixForm[S]
# Out:
# 1                              0
#
#
#
#
#
#
# >    0
#
#                                            1
#                                --------------------------
#                                                        2
#                                         (-1 + Sqrt[17])
#                                Sqrt[1 + ----------------]
# 0                                              16
#
#             -1 + Sqrt[17]
#      ----------------------------
#                                2
#                 (-1 + Sqrt[17])
#      4 Sqrt[1 + ----------------]
# >                      16
#
#                                            1
#                                -------------------------
#                                                       2
#                                         (1 + Sqrt[17])
#                                Sqrt[1 + ---------------]
# 0                                             16
#
#             -1 - Sqrt[17]
#      ---------------------------
#                               2
#                 (1 + Sqrt[17])
#      4 Sqrt[1 + ---------------]
# >                     16

# %% [markdown]
# ### Диагональная матрица

# %%
A1 = Transpose[S] . A . S;
MatrixForm[N[A1]]
# Out:
# 0.              0.              0.
#
#                                           -17
# 0.              -0.438447       5.55112 10
#
#
# 0.              0.              -4.56155

# %% [markdown]
# ### Преобразование коэффициентов линейной формы

# %%
B1 = Transpose[S] . B;
MatrixForm[N[B1], TableDirections -> Row]
# Out:
# 0.        5.61447   -0.691173

# %% [markdown]
# ### Каноническое уравнение

# %%
v = (Transpose[variables] . A1 . variables + Transpose[variables] . B1 + a0);
v = Function[{x, y, z}, Evaluate[v]];
FullSimplify[v] // TraditionalForm
# Out:
# FormBox[RowBox[{RowBox[{"{", RowBox[{"x", ",", "y", ",", "z"}], "}"}], "",
#
#
# >        RowBox[{RowBox[{"y", " ", RowBox[{"(",
#
#
# >              RowBox[{RowBox[{RowBox[{"(",
#
#
# >                    RowBox[{FractionBox[RowBox[{FractionBox["2",
#
#
# >                          SqrtBox[RowBox[{"1", "+",
#
#
# >                             RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                              "2"]}]}]]], "-",
#                       FractionBox["3",
#
#
# >                          SqrtBox[RowBox[{"1", "+",
#
#
# >                             RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]]}\
#
#
# >   ], SqrtBox[RowBox[{"1", "+", RowBox[{FractionBox["1", "16"], " ",
#
#
# >                            SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]],
#
#
# >                      "+", FractionBox[RowBox[{FractionBox["2",
#
#
# >                          SqrtBox[RowBox[{"1", "+",
#
#
# >                             RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]],
#
#
# >                         "-", RowBox[{FractionBox["2",
#
#
# >                            SqrtBox[RowBox[{"1", "+",
#
#
# >                               RowBox[{FractionBox["1", "16"], " ",
#
#
# >                               SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                               "2"]}]}]]]}]}],
#
#
# >                       SqrtBox[RowBox[{"1", "+",
#
#
# >                          RowBox[{FractionBox["1", "16"], " ",
#
#
# >                            SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                             "2"]}]}]]]}], ")"}], " ", "y"}], "+",
#
#
# >                RowBox[{RowBox[{"(",
#
#
# >                    RowBox[{FractionBox[RowBox[{FractionBox[RowBox[
#
#
# >                           {SqrtBox["17"], "-", RowBox[{"1"}]}],
#
#
# >                          RowBox[{"2", " ",
#
#
# >                            SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                              "2"]}]}]]}]], "-",
#
#
# >                         FractionBox[RowBox[{"3", " ",
#
#
# >                            RowBox[{"(",
#
#
# >                              RowBox[{RowBox[{"-", RowBox[{"1"}]}], "-",
#
#
# >                              SqrtBox["17"]}], ")"}]}],
#
#
# >                          RowBox[{"4", " ",
#
#
# >                            SqrtBox[RowBox[{"1", "+",
#
#
# >                               RowBox[{FractionBox["1", "16"], " ",
#
#
# >                               SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]}]]\
#
#
# >   }], SqrtBox[RowBox[{"1", "+", RowBox[{FractionBox["1", "16"], " ",
#
#
# >                            SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]],
#
#
# >                      "+", FractionBox[RowBox[{FractionBox[RowBox[{RowBox[
#
#
# >                             {"-", RowBox[{"1"}]}], "-", SqrtBox["17"]}],
#
#
# >                          RowBox[{"2", " ",
#
#
# >                            SqrtBox[RowBox[{"1", "+",
#
#
# >                               RowBox[{FractionBox["1", "16"], " ",
#
#
# >                               SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}],\
#
# >    "2"]}]}]]}]]\
# , "-", RowBox[{FractionBox[RowBox[{SqrtBox["17"], "-",\
#
# >    RowBox[{"1"}]}],
#                          RowBox[{"2", " ",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                               RowBox[{FractionBox["1", "16"], " ",
#
#
# >                               SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                               "2"]}]}]]}]]}]}],
#
#
# >                       SqrtBox[RowBox[{"1", "+",
#
#
# >                          RowBox[{FractionBox["1", "16"], " ",
#
#
# >                            SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                             "2"]}]}]]]}], ")"}], " ", "z"}]}], ")"}]}], "+",
#
#
# >          RowBox[{"z", " ", RowBox[{"(",
#            RowBox[{RowBox[{RowBox[{"(",
#
#
# >                    RowBox[{FractionBox[RowBox[{RowBox[{"(",
#
#
# >                           RowBox[{RowBox[{"-", RowBox[{"1"}]}], "-",
#
#
# >                             SqrtBox["17"]}], ")"}], " ",
#
#
# >                         RowBox[{"(",
#
#
# >                           RowBox[{FractionBox["2",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                             RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                              "2"]}]}]]], "-",
#
#
# >                             FractionBox["3",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]]\
#
#
# >   }], ")"}]}], RowBox[{"4", " ", SqrtBox[RowBox[{"1", "+",
#
#
# >                            RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}],\
#
# >    "2"]}]}]]}]]\
# , "+", FractionBox[RowBox[{RowBox[{"(",
#
#
# >                           RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}], " ",
#
#
# >                         RowBox[{"(",
#
#
# >                           RowBox[{FractionBox["2",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}],\
#
# >    "2"]}]}]]]\
# , "-", RowBox[{FractionBox["2", SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                              "2"]}]}]]]}]}], ")"}]}],
#
#
# >                       RowBox[{"4", " ",
#
#
# >                         SqrtBox[RowBox[{"1", "+",
#
#
# >                            RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                               "2"]}]}]]}]]}], ")"}], " ", "y"}], "+",
#
#
# >                RowBox[{RowBox[{"(",
#
#
# >                    RowBox[{FractionBox[RowBox[{RowBox[{"(",
#
#
# >                           RowBox[{RowBox[{"-", RowBox[{"1"}]}], "-",
#
#
# >                             SqrtBox["17"]}], ")"}], " ",
#
#
# >                         RowBox[{"(",
#
#
# >                           RowBox[{FractionBox[RowBox[{SqrtBox["17"], "-",
#
#
# >                              RowBox[{"1"}]}],
#
#
# >                              RowBox[{"2", " ",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                              "2"]}]}]]}]], "-",
#
#
# >                             FractionBox[RowBox[{"3", " ",
#
#
# >                              RowBox[{"(",
#
#
# >                              RowBox[{RowBox[{"-", RowBox[{"1"}]}], "-",
#
#
# >                              SqrtBox["17"]}], ")"}]}],
#
#
# >                              RowBox[{"4", " ",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]}]\
#
#
# >   ]}], ")"}]}], RowBox[{"4", " ", SqrtBox[RowBox[{"1", "+",
#
#
# >                            RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{"1", "+", SqrtBox["17"]}], ")"}],\
#
# >    "2"]}]}]]}]]\
# , "+", FractionBox[RowBox[{RowBox[{"(",
#
#
# >                           RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}], " ",
#
#
# >                         RowBox[{"(",
#
#
# >                           RowBox[{FractionBox[RowBox[{RowBox[{"-",
#
#
# >                              RowBox[{"1"}]}], "-", SqrtBox["17"]}],
#
#
# >                              RowBox[{"2", " ",
#
#
# >                              SqrtBox[RowBox[{"1", "+",
#
#
# >                              RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{"1", "+", SqrtBox["17"]}], ")"}], "2"]}]}]]}]\
#
#
# >   ], "-", RowBox[{FractionBox[RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}],
#
#
# >                               RowBox[{"2", " ",
#
#
# >                               SqrtBox[RowBox[{"1", "+",
#
#
# >                               RowBox[{FractionBox["1", "16"], " ",
#
#
# >                               SuperscriptBox[RowBox[{"(",
#
#
# >                              RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                               "2"]}]}]]}]]}]}], ")"}]}],
#
#
# >                       RowBox[{"4", " ",
#
#
# >                         SqrtBox[RowBox[{"1", "+",
#
#
# >                            RowBox[{FractionBox["1", "16"], " ",
#
#
# >                              SuperscriptBox[RowBox[{"(",
#
#
# >                               RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}],
#
#
# >                               "2"]}]}]]}]]}], ")"}], " ", "z"}]}], ")"}]}], "+",
#
#
# >          RowBox[{RowBox[{"(", RowBox[{FractionBox["4",
#
#
# >                 SqrtBox[RowBox[{"1", "+",
#
#
# >                    RowBox[{FractionBox["1", "16"], " ",
#
#
# >                      SuperscriptBox[RowBox[{"(",
#
#
# >                         RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}], "2"]}]}]]\
#
#
# >   ], "+", FractionBox["4", SqrtBox[RowBox[{"1", "+",
#
#
# >                    RowBox[{FractionBox["1", "16"], " ",
#
#
# >                      SuperscriptBox[RowBox[{"(", RowBox[{"1", "+", SqrtBox["17"]}],
#
#
# >                         ")"}], "2"]}]}]]]}], ")"}], " ", "y"}], "+",
#
#
# >          RowBox[{RowBox[{"(", RowBox[{FractionBox[RowBox[{SqrtBox["17"], "-",
#
#
# >                   RowBox[{"1"}]}], SqrtBox[RowBox[{"1", "+",
#
#
# >                    RowBox[{FractionBox["1", "16"], " ",
#
#
# >                      SuperscriptBox[RowBox[{"(",
#
#
# >                         RowBox[{SqrtBox["17"], "-", RowBox[{"1"}]}], ")"}], "2"]}]}]]\
#
#
# >   ], "+", FractionBox[RowBox[{RowBox[{"-", RowBox[{"1"}]}], "-", SqrtBox["17"]}],
#
#
# >                 SqrtBox[RowBox[{"1", "+",
#
#
# >                    RowBox[{FractionBox["1", "16"], " ",
#
#
# >                      SuperscriptBox[RowBox[{"(", RowBox[{"1", "+", SqrtBox["17"]}],
#
#
# >                         ")"}], "2"]}]}]]]}], ")"}], " ", "z"}], "-", "12"}]}],
#
#
# >      TraditionalForm]

# %%
RegionPlot3D[u[x, y, z] >= 0, {x, -10, 10}, {y, -10, 10}, {z, -10, 10}]
# Out:
# -Graphics3D-

# %%
RegionPlot3D[v[x, y, z] >= 0, {x, -10, 10}, {y, -10, 10}, {z, -10, 10}]
# Out:
# -Graphics3D-
